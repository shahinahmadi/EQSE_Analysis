# %% [markdown]
# ### Organizing and importing data to Canadian landed price list

# %%
import numpy
import csv
import pandas as pd



newdata_CAD=pd.read_excel("newdata.xlsx", sheet_name='CAD')
newdata_CAD
# Out:
#   Unnamed: 0 Unnamed: 1               Unnamed: 2 Unnamed: 3  Unnamed: 4    WS  \
# 0       JOUN        NaN                      NaN        NaN         NaN    WS
# 1      ITEMF      ITEML              Description      Cubes         NaN    10
# 2   30216-01   37216-01           JOAN 83IN SOFA       31.3         NaN   600
# 3   30216-02   37216-02               JOAN CHAIR       13.4         NaN  1600
# 4   30216-03   37216-03            JOAN LOVESEAT       23.1         NaN  2600
# 5   30216-04   37216-04             JOAN OTTOMAN        4.6         NaN  3600
# 6   30216-24   37216-24       JOAN EXTENDED SEAT       10.3         NaN  4600
# 7   30216-S3   37216-S3  JOAN 87IN EXTENDED SOFA       32.8         NaN  5600
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 34  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1        20.0        30.0        40.0        50.0  ...            I
# ...

# %%
from itertools import zip_longest
my_newdata1 = newdata_CAD.iloc[1: , :]
my_newdata1
my_newdata1.to_csv('data11.csv', header=False, index=False)
my_newdata2= pd.read_csv("data11.csv")
my_newdata2
my_newdata3=my_newdata2.drop(['Cubes', 'Unnamed: 4', 'Unnamed: 11', 
                              'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 24',
                              'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 35'], axis=1)
my_newdata3.to_csv("data12.csv")
pd.set_option("display.max_columns",None)
my_newdata3=pd.read_csv("data12.csv", 
names=['ITEM_F', 'ITEM_L', 'Description','Grade10L','Grade20L','Grade30L','Grade40L','Grade50L','Grade60L','FL','IL','Grade100L', 
'Grade200L','Grade300L','Grade400L','Grade500L','Grade600L','Grade700L','Grade800L','Grade10X', 'Grade20X','Grade30X',
'Grade40X','Grade50X', 'Grade60X', 'FX', 'IX','Grade100X', 'Grade200X', 'Grade300X','Grade400X','Grade500X', 
'Grade600X','Grade700X', 'Grade800X'])
my_newdata4_CAD=my_newdata3.iloc[1: , :]
length=len(my_newdata4_CAD['ITEM_F'])


    
    

    
LPriceListName=[]
LCatalog=[]
LGradeGroup=[]
LPrice=[]
GradeNumber_Fabric=[10,20,30,40,50,60,'F','I']
GradeNumber_Leather=[100,200,300,400,500,600,700,800]


print("------------------------------------------Organizng the data----------------------------------------------")

print("************************************Fabric*********************************************")


for i in my_newdata4_CAD["ITEM_F"]:
    for j in numpy.arange(1,9,1):
        LPriceListName.append('ufca 1711e v3')
        
    

for i in my_newdata4_CAD["ITEM_F"]:
      for j in numpy.arange(1, 9, 1):
                 LCatalog.append(i) 


for i in my_newdata4_CAD["ITEM_F"]:
    for j in GradeNumber_Fabric:
           LGradeGroup.append(j)



for i in range(0,length,1):
    LPrice.append(my_newdata4_CAD.Grade10L[i])
    LPrice.append(my_newdata4_CAD.Grade20L[i])
    LPrice.append(my_newdata4_CAD.Grade30L[i])
    LPrice.append(my_newdata4_CAD.Grade40L[i])
    LPrice.append(my_newdata4_CAD.Grade50L[i])
    LPrice.append(my_newdata4_CAD.Grade60L[i])
    LPrice.append(float(my_newdata4_CAD.FL[i]))
    LPrice.append(float(my_newdata4_CAD.IL[i]))
    
    



print("***********************************Leather*************************************************")

for i in my_newdata4_CAD["ITEM_L"]:
    for j in numpy.arange(1,9,1):
        LPriceListName.append("ufca 1711e v4")


    
for i in my_newdata4_CAD["ITEM_L"]:
      for j in numpy.arange(1, 9, 1):
                 LCatalog.append(i) 
                
                
for i in my_newdata4_CAD["ITEM_L"]:
    for j in GradeNumber_Leather:
           LGradeGroup.append(j)
            
            
for i in range(0,length,1):
    LPrice.append(my_newdata4_CAD.Grade100L[i])
    LPrice.append(my_newdata4_CAD.Grade200L[i])
    LPrice.append(my_newdata4_CAD.Grade300L[i])
    LPrice.append(my_newdata4_CAD.Grade400L[i])
    LPrice.append(my_newdata4_CAD.Grade500L[i])
    LPrice.append(my_newdata4_CAD.Grade600L[i])
    LPrice.append(my_newdata4_CAD.Grade700L[i])
    LPrice.append(my_newdata4_CAD.Grade800L[i])
    

            


print("------------------------------End of data organization---------------------------------------------")
# Out:
# ------------------------------------------Organizng the data----------------------------------------------
# ************************************Fabric*********************************************
# ***********************************Leather*************************************************
# ------------------------------End of data organization---------------------------------------------

# %% [markdown]
# ### Organizing and importing data to US landed price list

# %%
import numpy
import csv
import pandas as pd



newdata_US=pd.read_excel("newdata.xlsx", sheet_name='USD')

# %%
from itertools import zip_longest
my_newdata1 = newdata_US.iloc[1: , :]
my_newdata1
my_newdata1.to_csv('data11.csv', header=False, index=False)
my_newdata2= pd.read_csv("data11.csv")
my_newdata2
my_newdata3=my_newdata2.drop(['Cubes', 'Unnamed: 4', 'Unnamed: 11', 
                              'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 24',
                              'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 35'], axis=1)
my_newdata3.to_csv("data12.csv")
pd.set_option("display.max_columns",None)
my_newdata3=pd.read_csv("data12.csv", 
names=['ITEM_F', 'ITEM_L', 'Description','Grade10L','Grade20L','Grade30L','Grade40L','Grade50L','Grade60L','FL','IL','Grade100L', 
'Grade200L','Grade300L','Grade400L','Grade500L','Grade600L','Grade700L','Grade800L','Grade10X', 'Grade20X','Grade30X',
'Grade40X','Grade50X', 'Grade60X', 'FX', 'IX','Grade100X', 'Grade200X', 'Grade300X','Grade400X','Grade500X', 
'Grade600X','Grade700X', 'Grade800X'])
my_newdata4_US=my_newdata3.iloc[1: , :]
length=len(my_newdata4_CAD['ITEM_F'])


    
    
GradeNumber_Fabric=[10,20,30,40,50,60,'F','I']
GradeNumber_Leather=[100,200,300,400,500,600,700,800]


print("------------------------------------------Organizng the data----------------------------------------------")

print("************************************Fabric*********************************************")


for i in my_newdata4_US["ITEM_F"]:
    for j in numpy.arange(1,9,1):
        LPriceListName.append('ufmx 1711e v4')
        
    

for i in my_newdata4_US["ITEM_F"]:
      for j in numpy.arange(1, 9, 1):
                 LCatalog.append(i) 


for i in my_newdata4_US["ITEM_F"]:
    for j in GradeNumber_Fabric:
           LGradeGroup.append(j)



for i in range(0,length,1):
    LPrice.append(my_newdata4_US.Grade10L[i])
    LPrice.append(my_newdata4_US.Grade20L[i])
    LPrice.append(my_newdata4_US.Grade30L[i])
    LPrice.append(my_newdata4_US.Grade40L[i])
    LPrice.append(my_newdata4_US.Grade50L[i])
    LPrice.append(my_newdata4_US.Grade60L[i])
    LPrice.append(float(my_newdata4_US.FL[i]))
    LPrice.append(float(my_newdata4_US.IL[i]))


print("***********************************Leather*************************************************")

for i in my_newdata4_US["ITEM_L"]:
    for j in numpy.arange(1,9,1):
        LPriceListName.append("ufmx 1711e v4")


    
for i in my_newdata4_US["ITEM_L"]:
      for j in numpy.arange(1, 9, 1):
                 LCatalog.append(i) 
                
                
for i in my_newdata4_US["ITEM_L"]:
    for j in GradeNumber_Leather:
           LGradeGroup.append(j)
            
            
for i in range(0,length,1):
    LPrice.append(my_newdata4_US.Grade100L[i])
    LPrice.append(my_newdata4_US.Grade200L[i])
    LPrice.append(my_newdata4_US.Grade300L[i])
    LPrice.append(my_newdata4_US.Grade400L[i])
    LPrice.append(my_newdata4_US.Grade500L[i])
    LPrice.append(my_newdata4_US.Grade600L[i])
    LPrice.append(my_newdata4_US.Grade700L[i])
    LPrice.append(my_newdata4_US.Grade800L[i])
    
    
Table=[LPriceListName,LCatalog,LGradeGroup,LPrice]

export_data = zip_longest(*Table, fillvalue = '')
with open('Upload_L.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("PriceList", "Catalog", "GradeGroup", "Price"))
      wr.writerows(export_data)
myfile.close()

df1=pd.read_csv('Upload_L.csv')
writer=ExcelWriter("Upload_L_X.xlsx")
df1.to_excel(writer,sheet_name='Sheet_L', index=False)
print("------------------------------End of data organization---------------------------------------------")
    
print("LPrice list name")
print(LPriceListName)
print("Length of LPrice list name")
print(len(LPriceListName))
print("LCatalog")
print(LCatalog)
print("Length of LCatalog")
print(len(LCatalog))
print("LGradeGroup")
print(LGradeGroup)
print("Length of LGradeGroup")
print(len(LGradeGroup))
print("LPrice")
print(LPrice)
print("Length of LPrice")
print(len(LPrice))
# Out:
# ------------------------------------------Organizng the data----------------------------------------------
# ************************************Fabric*********************************************
# ***********************************Leather*************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d6c83a785a34> in <module>
#      97
#      98 df1=pd.read_csv('Upload_L.csv')
# ---> 99 writer=ExcelWriter("Upload_L_X.xlsx")
#     100 df1.to_excel(writer,sheet_name='Sheet_L', index=False)
#     101 print("------------------------------End of data organization---------------------------------------------")
#
# NameError: name 'ExcelWriter' is not defined

# %% [markdown]
# ### Importing data to Canadian EXWORK price list

# %%
print("------------------------------------------Organizng the data----------------------------------------------")

print("************************************Fabric(EXWORK CAD)*********************************************")

XPriceListName=[]
XCatalog=[]
XGradeGroup=[]
XPrice=[]

for i in my_newdata4_CAD["ITEM_F"]:
    for j in numpy.arange(1,9,1):
        XPriceListName.append('EQ3 EXW CA v4')
        
    

for i in my_newdata4_CAD["ITEM_F"]:
      for j in numpy.arange(1, 9, 1):
                 XCatalog.append(i) 


for i in my_newdata4_CAD["ITEM_F"]:
    for j in GradeNumber_Fabric:
           XGradeGroup.append(j)



for i in range(0,length,1):
    XPrice.append(my_newdata4_CAD.Grade10X[i])
    XPrice.append(my_newdata4_CAD.Grade20X[i])
    XPrice.append(my_newdata4_CAD.Grade30X[i])
    XPrice.append(my_newdata4_CAD.Grade40X[i])
    XPrice.append(my_newdata4_CAD.Grade50X[i])
    XPrice.append(my_newdata4_CAD.Grade60X[i])
    XPrice.append(float(my_newdata4_CAD.FX[i]))
    XPrice.append(float(my_newdata4_CAD.IX[i]))


print("***********************************Leather(EXWORK CAD)*************************************************")

for i in my_newdata4_CAD["ITEM_L"]:
    for j in numpy.arange(1,9,1):
        XPriceListName.append("EQ3 EXW CA v4")


    
for i in my_newdata4_CAD["ITEM_L"]:
      for j in numpy.arange(1, 9, 1):
                 XCatalog.append(i) 
                
                
for i in my_newdata4_CAD["ITEM_L"]:
    for j in GradeNumber_Leather:
           XGradeGroup.append(j)
            
            
for i in range(0,length,1):
    XPrice.append(my_newdata4_CAD.Grade100X[i])
    XPrice.append(my_newdata4_CAD.Grade200X[i])
    XPrice.append(my_newdata4_CAD.Grade300X[i])
    XPrice.append(my_newdata4_CAD.Grade400X[i])
    XPrice.append(my_newdata4_CAD.Grade500X[i])
    XPrice.append(my_newdata4_CAD.Grade600X[i])
    XPrice.append(my_newdata4_CAD.Grade700X[i])
    XPrice.append(my_newdata4_CAD.Grade800X[i])
    

print("------------------------------End of data organization---------------------------------------------")
# Out:
# ------------------------------------------Organizng the data----------------------------------------------
# ************************************Fabric(EXWORK CAD)*********************************************
# ***********************************Leather(EXWORK CAD)*************************************************
# ------------------------------End of data organization---------------------------------------------

# %% [markdown]
# ### Importing data to US EXWORK price list

# %%
print("------------------------------------------Organizng the data----------------------------------------------")

print("************************************Fabric(EXWORK US)*********************************************")

from pandas import ExcelWriter
from pandas import ExcelFile

for i in my_newdata4_US["ITEM_F"]:
    for j in numpy.arange(1,9,1):
        XPriceListName.append('EQ3 EXW US v4')
        
    

for i in my_newdata4_US["ITEM_F"]:
      for j in numpy.arange(1, 9, 1):
                 XCatalog.append(i) 


for i in my_newdata4_US["ITEM_F"]:
    for j in GradeNumber_Fabric:
           XGradeGroup.append(j)



for i in range(0,length,1):
    XPrice.append(my_newdata4_US.Grade10X[i])
    XPrice.append(my_newdata4_US.Grade20X[i])
    XPrice.append(my_newdata4_US.Grade30X[i])
    XPrice.append(my_newdata4_US.Grade40X[i])
    XPrice.append(my_newdata4_US.Grade50X[i])
    XPrice.append(my_newdata4_US.Grade60X[i])
    XPrice.append(float(my_newdata4_US.FX[i]))
    XPrice.append(float(my_newdata4_US.IX[i]))


print("***********************************Leather(EXWORK US)*************************************************")

for i in my_newdata4_US["ITEM_L"]:
    for j in numpy.arange(1,9,1):
        XPriceListName.append("EQ3 EXW US v4")


    
for i in my_newdata4_US["ITEM_L"]:
      for j in numpy.arange(1, 9, 1):
                 XCatalog.append(i) 
                
                
for i in my_newdata4_US["ITEM_L"]:
    for j in GradeNumber_Leather:
           XGradeGroup.append(j)
            
            
for i in range(0,length,1):
    XPrice.append(my_newdata4_US.Grade100X[i])
    XPrice.append(my_newdata4_US.Grade200X[i])
    XPrice.append(my_newdata4_US.Grade300X[i])
    XPrice.append(my_newdata4_US.Grade400X[i])
    XPrice.append(my_newdata4_US.Grade500X[i])
    XPrice.append(my_newdata4_US.Grade600X[i])
    XPrice.append(my_newdata4_US.Grade700X[i])
    XPrice.append(my_newdata4_US.Grade800X[i])
    

            
Table=[XPriceListName,XCatalog,XGradeGroup,XPrice]

export_data = zip_longest(*Table, fillvalue = '')
with open('Upload_X.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("PriceList", "Catalog", "GradeGroup", "Price"))
      wr.writerows(export_data)
myfile.close()
df2=pd.read_csv('Upload_X.csv')
#writer=ExcelWriter("Upload_L_X.xlsx")
df2.to_excel(writer,sheet_name='Sheet_X', index=False)
writer.save()
print("------------------------------End of data organization---------------------------------------------")   
    
print("XPrice list name")
print(XPriceListName)
print("Lenght XPrice list name")
print(len(XPriceListName))
print("XCatalog")
print(XCatalog)
print("Length of XCatalog")
print(len(XCatalog))
print("XGradeGroup")
print(XGradeGroup)
print("Length of XGradeGroup")
print(len(XGradeGroup))
print("XPrice")
print(XPrice)
print("Length of XPrice")
print(len(XPrice))
# Out:
# ------------------------------------------Organizng the data----------------------------------------------
# ************************************Fabric(EXWORK US)*********************************************
# ***********************************Leather(EXWORK US)*************************************************
# ------------------------------End of data organization---------------------------------------------
# XPrice list name
# ...
